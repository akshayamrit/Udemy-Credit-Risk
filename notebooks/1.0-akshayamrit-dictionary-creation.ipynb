# %%
import pandas as pd
import os
os.getcwd()
pd.set_option('max_columns', None)
pd.set_option('max_rows', 100)

# %%
loan_data_original = pd.read_csv(r'D:\Loyalytics\Credit Risk Competency Development\Udemy Course\Udemy-Credit-Risk\data\raw\loan_data_2007_2014.csv')
# Out:
# C:\ProgramData\Anaconda3\envs\venv_credit_risk\lib\site-packages\IPython\core\interactiveshell.py:3457: DtypeWarning: Columns (20) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
loan_data_LoanStats = pd.read_excel(r'D:\Loyalytics\Credit Risk Competency Development\Udemy Course\Udemy-Credit-Risk\references\LCDataDictionary.xlsx', sheet_name='LoanStats')
loan_data_LoanStats['Source'] = 'LoanStats'
loan_data_LoanStats = loan_data_LoanStats.loc[~loan_data_LoanStats['LoanStatNew'].isna()]
loan_data_LoanStats.columns = ['Field', 'Description', 'Source']
loan_data_browseNotes = pd.read_excel(r'D:\Loyalytics\Credit Risk Competency Development\Udemy Course\Udemy-Credit-Risk\references\LCDataDictionary.xlsx', sheet_name='browseNotes')
loan_data_browseNotes['Source'] = 'browseNotes'
loan_data_browseNotes = loan_data_browseNotes.loc[~loan_data_browseNotes['BrowseNotesFile'].isna()]
loan_data_browseNotes.columns = ['Field', 'Description', 'Source']
loan_data_RejectStats = pd.read_excel(r'D:\Loyalytics\Credit Risk Competency Development\Udemy Course\Udemy-Credit-Risk\references\LCDataDictionary.xlsx', sheet_name='RejectStats')
loan_data_RejectStats['Source'] = 'RejectStats'
loan_data_RejectStats = loan_data_RejectStats.loc[~loan_data_RejectStats['RejectStats File'].isna()]
loan_data_RejectStats.columns = ['Field', 'Description', 'Source']
final_dict = pd.concat([loan_data_LoanStats, loan_data_browseNotes, loan_data_RejectStats])
final_dict.drop_duplicates(['Field', 'Description'], inplace=True)
final_dict.set_index('Field', inplace=True)
# Out:
# C:\ProgramData\Anaconda3\envs\venv_credit_risk\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)

# %%
loan_data_original.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 466285 entries, 0 to 466284
# Data columns (total 75 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   Unnamed: 0                   466285 non-null  int64
#  1   id                           466285 non-null  int64
#  2   member_id                    466285 non-null  int64
#  3   loan_amnt                    466285 non-null  int64
#  4   funded_amnt                  466285 non-null  int64
#  5   funded_amnt_inv              466285 non-null  float64
#  6   term                         466285 non-null  object
#  7   int_rate                     466285 non-null  float64
#  8   installment                  466285 non-null  float64
#  9   grade                        466285 non-null  object
#  10  sub_grade                    466285 non-null  object
#  11  emp_title                    438697 non-null  object
#  12  emp_length                   445277 non-null  object
#  13  home_ownership               466285 non-null  object
#  14  annual_inc                   466281 non-null  float64
#  15  verification_status          466285 non-null  object
#  16  issue_d                      466285 non-null  object
#  17  loan_status                  466285 non-null  object
#  18  pymnt_plan                   466285 non-null  object
#  19  url                          466285 non-null  object
#  20  desc                         125983 non-null  object
#  21  purpose                      466285 non-null  object
#  22  title                        466265 non-null  object
#  23  zip_code                     466285 non-null  object
#  24  addr_state                   466285 non-null  object
#  25  dti                          466285 non-null  float64
#  26  delinq_2yrs                  466256 non-null  float64
#  27  earliest_cr_line             466256 non-null  object
#  28  inq_last_6mths               466256 non-null  float64
#  29  mths_since_last_delinq       215934 non-null  float64
#  30  mths_since_last_record       62638 non-null   float64
#  31  open_acc                     466256 non-null  float64
#  32  pub_rec                      466256 non-null  float64
#  33  revol_bal                    466285 non-null  int64
#  34  revol_util                   465945 non-null  float64
#  35  total_acc                    466256 non-null  float64
#  36  initial_list_status          466285 non-null  object
#  37  out_prncp                    466285 non-null  float64
#  38  out_prncp_inv                466285 non-null  float64
#  39  total_pymnt                  466285 non-null  float64
#  40  total_pymnt_inv              466285 non-null  float64
#  41  total_rec_prncp              466285 non-null  float64
#  42  total_rec_int                466285 non-null  float64
#  43  total_rec_late_fee           466285 non-null  float64
#  44  recoveries                   466285 non-null  float64
#  45  collection_recovery_fee      466285 non-null  float64
#  46  last_pymnt_d                 465909 non-null  object
#  47  last_pymnt_amnt              466285 non-null  float64
#  48  next_pymnt_d                 239071 non-null  object
#  49  last_credit_pull_d           466243 non-null  object
#  50  collections_12_mths_ex_med   466140 non-null  float64
#  51  mths_since_last_major_derog  98974 non-null   float64
#  52  policy_code                  466285 non-null  int64
#  53  application_type             466285 non-null  object
#  54  annual_inc_joint             0 non-null       float64
#  55  dti_joint                    0 non-null       float64
#  56  verification_status_joint    0 non-null       float64
#  57  acc_now_delinq               466256 non-null  float64
#  58  tot_coll_amt                 396009 non-null  float64
#  59  tot_cur_bal                  396009 non-null  float64
#  60  open_acc_6m                  0 non-null       float64
#  61  open_il_6m                   0 non-null       float64
#  62  open_il_12m                  0 non-null       float64
#  63  open_il_24m                  0 non-null       float64
#  64  mths_since_rcnt_il           0 non-null       float64
#  65  total_bal_il                 0 non-null       float64
#  66  il_util                      0 non-null       float64
#  67  open_rv_12m                  0 non-null       float64
#  68  open_rv_24m                  0 non-null       float64
#  69  max_bal_bc                   0 non-null       float64
#  70  all_util                     0 non-null       float64
#  71  total_rev_hi_lim             396009 non-null  float64
#  72  inq_fi                       0 non-null       float64
#  73  total_cu_tl                  0 non-null       float64
#  74  inq_last_12m                 0 non-null       float64
# dtypes: float64(46), int64(7), object(22)
# memory usage: 266.8+ MB

# %%
column_name_dict = dict()
column_desc_list = list()
for i in loan_data_original.columns:
    try:
        column_desc_list.append(final_dict.loc[i,'Description'])
    except KeyError:
        column_desc_list.append('NA')
column_name_dict['Column'] = loan_data_original.columns.values
column_name_dict['Description'] = column_desc_list
pd.DataFrame(column_name_dict)
# Out:
#                          Column  \
# 0                    Unnamed: 0
# 1                            id
# 2                     member_id
# 3                     loan_amnt
# 4                   funded_amnt
# 5               funded_amnt_inv
# 6                          term
# 7                      int_rate
# 8                   installment
# 9                         grade
# 10                    sub_grade
# 11                    emp_title
# 12                   emp_length
# 13               home_ownership
# 14                   annual_inc
# 15          verification_status
# 16                      issue_d
# 17                  loan_status
# 18                   pymnt_plan
# 19                          url
# 20                         desc
# 21                      purpose
# 22                        title
# 23                     zip_code
# 24                   addr_state
# 25                          dti
# 26                  delinq_2yrs
# 27             earliest_cr_line
# 28               inq_last_6mths
# 29       mths_since_last_delinq
# 30       mths_since_last_record
# 31                     open_acc
# 32                      pub_rec
# 33                    revol_bal
# 34                   revol_util
# 35                    total_acc
# 36          initial_list_status
# 37                    out_prncp
# 38                out_prncp_inv
# 39                  total_pymnt
# 40              total_pymnt_inv
# 41              total_rec_prncp
# 42                total_rec_int
# 43           total_rec_late_fee
# 44                   recoveries
# 45      collection_recovery_fee
# 46                 last_pymnt_d
# 47              last_pymnt_amnt
# 48                 next_pymnt_d
# 49           last_credit_pull_d
# 50   collections_12_mths_ex_med
# 51  mths_since_last_major_derog
# 52                  policy_code
# 53             application_type
# 54             annual_inc_joint
# 55                    dti_joint
# 56    verification_status_joint
# 57               acc_now_delinq
# 58                 tot_coll_amt
# 59                  tot_cur_bal
# 60                  open_acc_6m
# 61                   open_il_6m
# 62                  open_il_12m
# 63                  open_il_24m
# 64           mths_since_rcnt_il
# 65                 total_bal_il
# 66                      il_util
# 67                  open_rv_12m
# 68                  open_rv_24m
# 69                   max_bal_bc
# 70                     all_util
# 71             total_rev_hi_lim
# 72                       inq_fi
# 73                  total_cu_tl
# 74                 inq_last_12m
#
#                                           Description
# 0                                                  NA
# 1       A unique LC assigned ID for the loan listing.
# 2    A unique LC assigned Id for the borrower member.
# 3   The listed amount of the loan applied for by t...
# 4   The total amount committed to that loan at tha...
# 5   The total amount committed by investors for th...
# 6   The number of payments on the loan. Values are...
# 7                           Interest Rate on the loan
# 8   The monthly payment owed by the borrower if th...
# 9                              LC assigned loan grade
# 10                          LC assigned loan subgrade
# 11  The job title supplied by the Borrower when ap...
# 12  Employment length in years. Possible values ar...
# 13  The home ownership status provided by the borr...
# 14  The self-reported annual income provided by th...
# 15                                                 NA
# 16                The month which the loan was funded
# 17                         Current status of the loan
# 18  Indicates if a payment plan has been put in pl...
# 19             URL for the LC page with listing data.
# 20          Loan description provided by the borrower
# 21  A category provided by the borrower for the lo...
# 22            The loan title provided by the borrower
# 23  The first 3 numbers of the zip code provided b...
# 24  The state provided by the borrower in the loan...
# 25  A ratio calculated using the borrower’s total ...
# 26  The number of 30+ days past-due incidences of ...
# 27  The month the borrower's earliest reported cre...
# 28  The number of inquiries in past 6 months (excl...
# 29  The number of months since the borrower's last...
# 30  The number of months since the last public rec...
# 31  The number of open credit lines in the borrowe...
# 32                Number of derogatory public records
# 33                     Total credit revolving balance
# 34  Revolving line utilization rate, or the amount...
# 35  The total number of credit lines currently in ...
# 36  The initial listing status of the loan. Possib...
# 37  Remaining outstanding principal for total amou...
# 38  Remaining outstanding principal for portion of...
# 39  Payments received to date for total amount funded
# 40  Payments received to date for portion of total...
# 41                         Principal received to date
# 42                          Interest received to date
# 43                         Late fees received to date
# 44                     post charge off gross recovery
# 45                     post charge off collection fee
# 46                    Last month payment was received
# 47                 Last total payment amount received
# 48                        Next scheduled payment date
# 49  The most recent month LC pulled credit for thi...
# 50  Number of collections in 12 months excluding m...
# 51    Months since most recent 90-day or worse rating
# 52  publicly available policy_code=1\nnew products...
# 53  Indicates whether the loan is an individual ap...
# 54  The combined self-reported annual income provi...
# 55  A ratio calculated using the co-borrowers' tot...
# 56                                                 NA
# 57  The number of accounts on which the borrower i...
# 58                 Total collection amounts ever owed
# 59              Total current balance of all accounts
# 60             Number of open trades in last 6 months
# 61      Number of currently active installment trades
# 62  Number of installment accounts opened in past ...
# 63  Number of installment accounts opened in past ...
# 64  Months since most recent installment accounts ...
# 65  Total current balance of all installment accounts
# 66  Ratio of total current balance to high credit/...
# 67  Number of revolving trades opened in past 12 m...
# 68  Number of revolving trades opened in past 24 m...
# 69  Maximum current balance owed on all revolving ...
# 70              Balance to credit limit on all trades
# 71                                                 NA
# 72               Number of personal finance inquiries
# 73                           Number of finance trades
# 74       Number of credit inquiries in past 12 months
